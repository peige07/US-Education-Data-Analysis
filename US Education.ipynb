# %% [markdown]
# <div style="width: 95%; background-color: #fff87e; color: #0B638B; padding: 20px; border: 3px solid black; margin-bottom: 20px;border-radius:10px;">
#
# <h1>United States Education Analysis</h1
#
# For business inquiries or collaboration requests, you can reach me at <span style="font-weight: bold; color: black;">peige77@gmail.com</span>
#
# The data set contains various columns on US states enrollement, test scores and revenues. Dataset can be viewed in the file section of the repository.
#
# **Tools & Software utilized:**
#
# - Python with JupyterLab (loading, processing & EDA)
# - Excel (data visualization and dashboard creation)
# - Tableau (data visualization and dashboard)
#
# **Project structure:**
# - Project Objectives & Goals
# - Data Collection
# - Data Discovery, Cleaning & Preprocessing
# - Exploratory Data Analysis
# - Conclusions
# - Additional Visualizaitons (Excel & Tableau)

# %% [markdown]
# <div style="width:95%; background-color:#00296b; color:#ffffff; padding:20px; border: 3px solid black; border-radius: 20px;">
#
# <h2>Project Objectives & Goals:</h2>
#     <ul>
#         <li>Determine the correlation between total revenue and average 8th grade math scores</li>
#         <li>Determine the correlation between state expenditure and average 8th grade math scores</li>
#         <li>Identify the states with the most students</li>
#     </ul>
# </div>
#
# <p>Possible question determine the improvements in test scores in one particular state over a 20 year period
#     <br>
#     Hypothesis testing: H sub0 = null hypothesis: there is no correlation between total revenue and test scores</p>

# %% [markdown]
# <head>
#     <link rel= "stylesheet" href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style=" width:95%; color: white; background-color:#00296b ; border: 3px solid black; border-radius:20px; padding:20px; font:ontserrat;">
#
# <h2>Data Collection</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sci

# %%
#Data Loading
df = pd.read_csv(r'C:\Users\PM\Desktop\Data Analytics Projects\US Education\states_all.csv')

# %%
df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %% [markdown]
# <head>
#     <link rel= "stylesheet" href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style=" width:95%; color: white; background-color:#00296b ; border: 3px solid black; border-radius:20px; padding:20px; font:ontserrat;">
#
# <h2>Data Cleaning and Preprocessing</h2>
# <ul>
#     <li>Handling missng values</li>
#     <li>Addressing duplicate data</li>
#     <li>Dealing with outliers</li>
# </ul>

# %% [markdown]
# <head>
#     <link rel='stylesheet' href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style="background-color: black; color: white; padding: 20px; border: 2px solid #fff87e; border-radius: 20px; text-align: center; font-family: 'montserrat', sans-serif; font-weight: bold; font-size: 20px">
#
# <h4>Data Discovery</h4>
#
# </div>

# %%
columns = df.columns

for x in columns:
    print(x)
# Out:
# PRIMARY_KEY
# STATE
# YEAR
# ENROLL
# TOTAL_REVENUE
# FEDERAL_REVENUE
# STATE_REVENUE
# LOCAL_REVENUE
# TOTAL_EXPENDITURE
# INSTRUCTION_EXPENDITURE
# SUPPORT_SERVICES_EXPENDITURE
# OTHER_EXPENDITURE
# CAPITAL_OUTLAY_EXPENDITURE
# GRADES_PK_G
# GRADES_KG_G
# GRADES_4_G
# GRADES_8_G
# GRADES_12_G
# GRADES_1_8_G
# GRADES_9_12_G
# GRADES_ALL_G
# AVG_MATH_4_SCORE
# AVG_MATH_8_SCORE
# AVG_READING_4_SCORE
# AVG_READING_8_SCORE

# %%
df.shape
# Out:
# (1715, 25)

# %%
df.describe()
# Out:
#               YEAR        ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# count  1715.000000  1.224000e+03   1.275000e+03     1.275000e+03
# mean   2002.075219  9.175416e+05   9.102045e+06     7.677799e+05
# std       9.568621  1.066514e+06   1.175962e+07     1.146992e+06
# min    1986.000000  4.386600e+04   4.656500e+05     3.102000e+04
# 25%    1994.000000  2.645145e+05   2.189504e+06     1.899575e+05
# 50%    2002.000000  6.499335e+05   5.085826e+06     4.035480e+05
# 75%    2010.000000  1.010532e+06   1.084516e+07     8.279320e+05
# max    2019.000000  6.307022e+06   8.921726e+07     9.990221e+06
#
#        STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# count   1.275000e+03   1.275000e+03       1.275000e+03
# mean    4.223743e+06   4.110522e+06       9.206242e+06
# std     5.549735e+06   5.489562e+06       1.199279e+07
# min     0.000000e+00   2.209300e+04       4.816650e+05
# 25%     1.165776e+06   7.151210e+05       2.170404e+06
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1715 entries, 0 to 1714
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   PRIMARY_KEY                   1715 non-null   object
#  1   STATE                         1715 non-null   object
#  2   YEAR                          1715 non-null   int64
#  3   ENROLL                        1224 non-null   float64
#  4   TOTAL_REVENUE                 1275 non-null   float64
#  5   FEDERAL_REVENUE               1275 non-null   float64
#  6   STATE_REVENUE                 1275 non-null   float64
#  7   LOCAL_REVENUE                 1275 non-null   float64
#  8   TOTAL_EXPENDITURE             1275 non-null   float64
#  9   INSTRUCTION_EXPENDITURE       1275 non-null   float64
#  10  SUPPORT_SERVICES_EXPENDITURE  1275 non-null   float64
#  11  OTHER_EXPENDITURE             1224 non-null   float64
# ...

# %%
#We have several unnecessary columns so we will drop them

column_drops = ['FEDERAL_REVENUE','STATE_REVENUE','LOCAL_REVENUE','INSTRUCTION_EXPENDITURE','SUPPORT_SERVICES_EXPENDITURE','OTHER_EXPENDITURE',
                'CAPITAL_OUTLAY_EXPENDITURE','GRADES_PK_G','GRADES_KG_G','GRADES_12_G','GRADES_1_8_G','GRADES_9_12_G','AVG_MATH_4_SCORE',
                'AVG_READING_4_SCORE','AVG_READING_4_SCORE']
                
ndf= df.drop(column_drops, axis=1)
ndf.shape
# Out:
# (1715, 11)

# %% [markdown]
# <head>
#     <link rel='stylesheet' href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style="background-color: black; color: white; padding: 20px; border: 2px solid #fff87e; border-radius: 20px; text-align: center; font-family: 'montserrat', sans-serif; font-weight: bold; font-size: 20px">
#
# <h4>Handeling Missing Values</h4>
#
# </div>

# %%
#Handling Missing Value

missing_values = ndf.isnull().sum()
missing_values
# Out:
# PRIMARY_KEY               0
# STATE                     0
# YEAR                      0
# ENROLL                  491
# TOTAL_REVENUE           440
# TOTAL_EXPENDITURE       440
# GRADES_4_G               83
# GRADES_8_G               83
# GRADES_ALL_G             83
# AVG_MATH_8_SCORE       1113
# AVG_READING_8_SCORE    1153
# dtype: int64

# %%
#We are missing a substancial amount of necessary data in our dataframe
#We will replace the missing value with the mode of each column 
mode_imputation = ['ENROLL', 'TOTAL_REVENUE','TOTAL_EXPENDITURE','GRADES_4_G','GRADES_8_G','GRADES_ALL_G','AVG_MATH_8_SCORE']

for column in mode_imputation:
    mode = ndf[column].mode()[0]
    ndf[column].fillna(mode, inplace=True)

ndf.isnull().sum()
# Out:
# PRIMARY_KEY               0
# STATE                     0
# YEAR                      0
# ENROLL                    0
# TOTAL_REVENUE             0
# TOTAL_EXPENDITURE         0
# GRADES_4_G                0
# GRADES_8_G                0
# GRADES_ALL_G              0
# AVG_MATH_8_SCORE          0
# AVG_READING_8_SCORE    1153
# dtype: int64

# %% [markdown]
# <head>
#     <link rel='stylesheet' href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style="background-color: black; color:white; border: 2px solid #fff87e; text-align:center; font-weight: bold; font-family: 'Montserrat', sans-serif; padding: 20px; border-radius:20px; font-size:20px">
#
# <h4>Addressing Duplicate Data</h4>
#
# </div>

# %%
#checking for duplicate data
dup_data = ndf.duplicated()

for key,value in dup_data.items():
    if value == True:
        print(f'-{key}')

# %% [markdown]
# <div style="background-color:lightyellow; color:black; padding:20px;">
# When running the above cell nothing is returned indicating that we do not have any duplicate data present
# </div>

# %% [markdown]
# <head>
#     <link rel='stylesheet' href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style="background-color: black; color:white; border: 2px solid #fff87e; text-align:center; font-weight: bold; font-family: 'Montserrat', sans-serif; padding: 20px; border-radius:20px; font-size:20px">
#
# <h4>Dealing With Outliers</h4>
#
# </div>

# %%
#For this analysis we only want to compare data across states in a single year so we will choose the year 2000
ndf2000 = ndf[ndf['YEAR'] == 2000]

ndf2000.shape
# Out:
# (53, 11)

# %%
#We have 53 rows and only want to 50 states in our dataframe so we will remove the 3 non-state rows

invalid_rows = [416,1642,1643]

ndf2000 = ndf2000.drop(invalid_rows)

# %%
#Ensuring our extra 3 rows were dropped
ndf2000.shape
# Out:
# (50, 11)

# %%
#Identifying data types for future calculations
ndf2000.dtypes
# Out:
# PRIMARY_KEY             object
# STATE                   object
# YEAR                     int64
# ENROLL                 float64
# TOTAL_REVENUE          float64
# TOTAL_EXPENDITURE      float64
# GRADES_4_G             float64
# GRADES_8_G             float64
# GRADES_ALL_G           float64
# AVG_MATH_8_SCORE       float64
# AVG_READING_8_SCORE    float64
# dtype: object

# %%
#Checking for outliers in TOTAL_REVENUE

ndf2000['TOTAL_REVENUE'].describe()
# Out:
# count    5.000000e+01
# mean     7.574416e+06
# std      8.870072e+06
# min      7.873230e+05
# 25%      2.204559e+06
# 50%      4.737874e+06
# 75%      8.806067e+06
# max      4.662821e+07
# Name: TOTAL_REVENUE, dtype: float64

# %%
plt.figure(figsize=(5,5))
plt.boxplot(ndf2000['TOTAL_REVENUE'])
plt.show()

# %%
#Quick check that our quartiles are correct
q3 = np.percentile(ndf2000['TOTAL_REVENUE'], 75)
q1 = np.percentile(ndf2000['TOTAL_REVENUE'],25)
print(f'Quartile number 3: {q3}')
print(f'Quartile number 1: {q1}')

iqr = q3 - q1

print(f'Interquartile range: {iqr}')

upper_limit = q3 + 1.5 * iqr
lower_limit = q1 -1.5 * iqr

print(f'Upper Limit: {upper_limit}')
print(f'Lower Limit: {lower_limit}')

# Identify outliers
outliers = (ndf2000['TOTAL_REVENUE'] < lower_limit) | (ndf2000['TOTAL_REVENUE'] > upper_limit)

# Display the outliers
print("Outliers:")

for key, value in outliers.items():
    if value == True:
        print(f'-{key}')
# Out:
# Quartile number 3: 8806067.25
# Quartile number 1: 2204559.0
# Interquartile range: 6601508.25
# Upper Limit: 18708329.625
# Lower Limit: -7697703.375
# Outliers:
# -412
# -440
# -451

# %%
#Ill use IQR to determine outliers but incase your would like to use Z-Scores ill provide the code as well
z_total_revenue = (ndf2000['TOTAL_REVENUE'] - ndf2000['TOTAL_REVENUE'].mean())/ndf2000['TOTAL_REVENUE'].std()

outliers = (z_total_revenue > 3) | (z_total_revenue< -3)

for key,value in outliers.items():
    if value == True:
        print(f'Row #{key}, is an outlier')
# Out:
# Row #412, is an outlier

# %%
#We have 3 outliers present so I will check to see which states they are

revenue_outliers = [412, 440, 451]

for row_index in revenue_outliers:
    print(f"Outliers in TOTAL_REVENUE: {ndf2000.loc[row_index, 'PRIMARY_KEY']}")
# Out:
# Outliers in TOTAL_REVENUE: 2000_CALIFORNIA
# Outliers in TOTAL_REVENUE: 2000_NEW_YORK
# Outliers in TOTAL_REVENUE: 2000_TEXAS

# %% [markdown]
# <div style="background-color:lightyellow; color:black; padding:20px;">
# Based on the fact that the 3 outliers are the 3 largest states by population and total revenue in the US I will leave them
# </div>

# %%
ndf2000.head(1)
# Out:
#       PRIMARY_KEY    STATE  YEAR    ENROLL  TOTAL_REVENUE  TOTAL_EXPENDITURE  \
# 408  2000_ALABAMA  ALABAMA  2000  730184.0      4885917.0          5003267.0
#
#      GRADES_4_G  GRADES_8_G  GRADES_ALL_G  AVG_MATH_8_SCORE  \
# 408     59749.0     56951.0      739992.0             264.0
#
#      AVG_READING_8_SCORE
# 408                  NaN

# %%
plt.figure(figsize=(5,5))

plt.boxplot(ndf2000['TOTAL_EXPENDITURE'])

plt.show()

# %%
# Quick check that our quartiles are correct and to identify outliers for TOTAL_EXPENDITURE
q3 = np.percentile(ndf2000['TOTAL_EXPENDITURE'], 75)
q1 = np.percentile(ndf2000['TOTAL_EXPENDITURE'], 25)
print(f'Quartile number 3: {q3}')
print(f'Quartile number 1: {q1}')

iqr = q3 - q1

print(f'Interquartile range: {iqr}')

upper_limit = q3 + 1.5 * iqr
lower_limit = q1 - 1.5 * iqr

print(f'Upper Limit: {upper_limit}')
print(f'Lower Limit: {lower_limit}')

# Identify outliers
outliers = (ndf2000['TOTAL_EXPENDITURE'] < lower_limit) | (ndf2000['TOTAL_EXPENDITURE'] > upper_limit)

# Display the outliers
print("Outliers:")

for key, values in outliers.items():
    if values == True:
        print(f'-{key}')
# Out:
# Quartile number 3: 8995626.25
# Quartile number 1: 2165155.5
# Interquartile range: 6830470.75
# Upper Limit: 19241332.375
# Lower Limit: -8080550.625
# Outliers:
# -412
# -440
# -451

# %%
#Same outliers as our previous column
revenue_outliers = [412, 440, 451]

for row_index in revenue_outliers:
    print(f"Outliers in TOTAL_EXPENDITURE: {ndf2000.loc[row_index, 'PRIMARY_KEY']}")
# Out:
# Outliers in TOTAL_EXPENDITURE: 2000_CALIFORNIA
# Outliers in TOTAL_EXPENDITURE: 2000_NEW_YORK
# Outliers in TOTAL_EXPENDITURE: 2000_TEXAS

# %%
#Determining outliers in TOTAL_EXPENDITURE column
z_total_expenditure = (ndf2000['TOTAL_EXPENDITURE'] - ndf2000['TOTAL_EXPENDITURE'].mean())/ndf2000['TOTAL_EXPENDITURE'].std()

outliers = (z_total_expenditure > 3) | (z_total_expenditure< -3)

for key,value in outliers.items():
    if value == True:
        print(f'Row #{key}, is an outlier')
# Out:
# Row #412, is an outlier

# %% [markdown]
# <div style="background-color:lightyellow; color:black; padding:20px;">
#     Once again we will leave our 3 outliers due to the fact that they are the largest states, if you wanted to remove these 3 rows you could simply run the following python code:
# </div>
# <div style="background-color:lightyellow; color:black; padding:20px;">
# <mark>drop_outliers = [412, 440, 451]<br>
# ndf2000 = ndf2000.drop(drop_outliers)</mark></div>

# %% [markdown]
# Handling outliers:
# TO start tomorrow, average math and reading scores for 8th grade outliers
#
#
# EXPLORATORY Data analysis:
# determine states with highest enrollement
#
# once finished make a new data frame for the top 10 states in each category:
# - enrollment
# - total expenditure
# - total revenue
# - highest math
#
# in data viz section create visualizations for each of these

# %%
ndf2000.head(1)
# Out:
#       PRIMARY_KEY    STATE  YEAR    ENROLL  TOTAL_REVENUE  TOTAL_EXPENDITURE  \
# 408  2000_ALABAMA  ALABAMA  2000  730184.0      4885917.0          5003267.0
#
#      GRADES_4_G  GRADES_8_G  GRADES_ALL_G  AVG_MATH_8_SCORE  \
# 408     59749.0     56951.0      739992.0             264.0
#
#      AVG_READING_8_SCORE
# 408                  NaN

# %%
ndf2000['AVG_MATH_8_SCORE'].describe()
# Out:
# count     50.000000
# mean     275.200000
# std        9.531901
# min      254.000000
# 25%      269.000000
# 50%      276.500000
# 75%      284.500000
# max      287.000000
# Name: AVG_MATH_8_SCORE, dtype: float64

# %%
#Checking for outliers in AVG_MATH_8_SCORE	column
plt.figure(figsize=(5,5))
plt.boxplot(ndf2000['AVG_MATH_8_SCORE'])
plt.show()

# %% [markdown]
# <div style="background-color:lightyellow; color:black; padding:20px;">
# Based on our box plot and the describe function 2020's data for AVG_READING_8_SCORE must have been one of the columns that was filled in based on mean data earlier. Due to this we will only test scores for AVG_MATH_8_SCORE moving forward.
# </div>

# %% [markdown]
# <head>
#     <link rel= "stylesheet" href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style=" width:95%; color: white; background-color:#00296b ; border: 3px solid black; border-radius:20px; padding:20px; font:ontserrat;">
#
# <h2>Exploratory Data Analysis</h2>
# <ul>
#     <li>Determining correlations between variables</li>
#     <li>Univariate analysis</li>
#     <li>Bivariate analysis</li>
#     <li>Hypothesis testing</li>
# </ul>
#
# </div>

# %% [markdown]
# <head>
#     <link rel='stylesheet' href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style="background-color: black; color:white; border: 2px solid #fff87e; text-align:center; font-weight: bold; font-family: 'Montserrat', sans-serif; padding: 20px; border-radius:20px; font-size:20px">
#
# <h4>Correlations Between Variables</h4>
#
# </div>

# %%
ndf2000.head(1)
# Out:
#       PRIMARY_KEY    STATE  YEAR    ENROLL  TOTAL_REVENUE  TOTAL_EXPENDITURE  \
# 408  2000_ALABAMA  ALABAMA  2000  730184.0      4885917.0          5003267.0
#
#      GRADES_4_G  GRADES_8_G  GRADES_ALL_G  AVG_MATH_8_SCORE  \
# 408     59749.0     56951.0      739992.0             264.0
#
#      AVG_READING_8_SCORE
# 408                  NaN

# %%
ndf2000.corr(numeric_only=True)
# Out:
#                      YEAR    ENROLL  TOTAL_REVENUE  TOTAL_EXPENDITURE  \
# YEAR                  NaN       NaN            NaN                NaN
# ENROLL                NaN  1.000000       0.979324           0.975702
# TOTAL_REVENUE         NaN  0.979324       1.000000           0.998838
# TOTAL_EXPENDITURE     NaN  0.975702       0.998838           1.000000
# GRADES_4_G            NaN  0.999273       0.974742           0.969909
# GRADES_8_G            NaN  0.999244       0.974826           0.971204
# GRADES_ALL_G          NaN  0.999899       0.978252           0.974328
# AVG_MATH_8_SCORE      NaN -0.142099      -0.081746          -0.078195
# AVG_READING_8_SCORE   NaN       NaN            NaN                NaN
#
#                      GRADES_4_G  GRADES_8_G  GRADES_ALL_G  AVG_MATH_8_SCORE  \
# YEAR                        NaN         NaN           NaN               NaN
# ENROLL                 0.999273    0.999244      0.999899         -0.142099
# ...

# %%
ndf2000.dtypes
# Out:
# PRIMARY_KEY             object
# STATE                   object
# YEAR                     int64
# ENROLL                 float64
# TOTAL_REVENUE          float64
# TOTAL_EXPENDITURE      float64
# GRADES_4_G             float64
# GRADES_8_G             float64
# GRADES_ALL_G           float64
# AVG_MATH_8_SCORE       float64
# AVG_READING_8_SCORE    float64
# dtype: object

# %%
sns.heatmap(ndf2000.corr(numeric_only=True), annot=True, fmt='.1f', linewidth='.5', cmap='Blues')
plt.title("Correlation Between Variables", fontsize=18)
plt.show()

# %% [markdown]
# <head>
#     <link rel='stylesheet' href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style="background-color: black; color:white; border: 2px solid #fff87e; text-align:center; font-weight: bold; font-family: 'Montserrat', sans-serif; padding: 20px; border-radius:20px; font-size:20px">
#
# <h4>Univariate Analysis</h4>
#
# </div>

# %%
enrollment_descending= ndf2000.groupby('STATE')['ENROLL'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))

sns.histplot(enrollment_descending, bins=10, kde=True, color='skyblue')
plt.title('Distribution of Enrollement')
plt.xlabel('TOTAL_REVENUE')
plt.ylabel('Frequency')
sns.set_theme(style='darkgrid')

plt.show()

# %%
#Determining the top 10 states with the highest enrollment
top10_enroll= ndf2000.groupby('STATE')['ENROLL'].sum().sort_values(ascending=False).nlargest(10)

print(top10_enroll)

for key, value in top10_enroll.items():
    print(f'{key}')
# Out:
# STATE
# CALIFORNIA      5941946.0
# TEXAS           3965971.0
# NEW_YORK        2861478.0
# FLORIDA         2377271.0
# ILLINOIS        2003839.0
# OHIO            1822566.0
# PENNSYLVANIA    1782444.0
# MICHIGAN        1700074.0
# GEORGIA         1422941.0
# NEW_JERSEY      1279542.0
# Name: ENROLL, dtype: float64
# CALIFORNIA
# TEXAS
# NEW_YORK
# FLORIDA
# ILLINOIS
# OHIO
# PENNSYLVANIA
# MICHIGAN
# GEORGIA
# NEW_JERSEY

# %%
#Validating data for TOTAL_REVENUE Column
plt.figure(figsize=(10, 6))

sns.histplot(top10_enroll, bins=10, kde=True, color='skyblue')
plt.title('Distribution of Enrollement')
plt.xlabel('TOTAL_REVENUE')
plt.ylabel('Frequency')
sns.set_theme(style='darkgrid')

plt.show()

# %%
ndf2000['TOTAL_REVENUE'].describe()
# Out:
# count    5.000000e+01
# mean     7.574416e+06
# std      8.870072e+06
# min      7.873230e+05
# 25%      2.204559e+06
# 50%      4.737874e+06
# 75%      8.806067e+06
# max      4.662821e+07
# Name: TOTAL_REVENUE, dtype: float64

# %%
#Validating data for TOTAL_REVENUE Column
plt.figure(figsize=(10, 6))

sns.histplot(ndf2000['TOTAL_REVENUE'], bins=10, kde=True, color='skyblue')
plt.title('Distribution of TOTAL_REVENUE')
plt.xlabel('TOTAL_REVENUE')
plt.ylabel('Frequency')
sns.set_theme(style='darkgrid')

plt.show()

# %% [markdown]
# <hr>

# %%
ndf2000['TOTAL_EXPENDITURE'].describe()
# Out:
# count    5.000000e+01
# mean     7.706372e+06
# std      9.034884e+06
# min      7.699230e+05
# 25%      2.165156e+06
# 50%      4.884244e+06
# 75%      8.995626e+06
# max      4.582975e+07
# Name: TOTAL_EXPENDITURE, dtype: float64

# %%
#Validating data for TOTAL_EXPENDITURE column
plt.figure(figsize=(10,6))

sns.histplot(ndf2000['TOTAL_EXPENDITURE'], bins=10, color='yellow', kde=True)
plt.xlabel('TOTAL_EXPENDITURE')
plt.ylabel('Frequency')
plt.title('Distribution of TOTAL_EXPENDITURE')

plt.show()

# %% [markdown]
# <hr>

# %%
ndf2000['AVG_MATH_8_SCORE'].describe()
# Out:
# count     50.000000
# mean     275.200000
# std        9.531901
# min      254.000000
# 25%      269.000000
# 50%      276.500000
# 75%      284.500000
# max      287.000000
# Name: AVG_MATH_8_SCORE, dtype: float64

# %%
#Validating data for AVG_MATH_8_SCORE column
plt.figure(figsize=(10,6))

sns.histplot(ndf2000['AVG_MATH_8_SCORE'], bins= 10, kde=True, color='red')
plt.xlabel('AVG_MATH_8_SCORE')
plt.ylabel('Fequency')
plt.title('Distribution of AVG_MATH_8_SCORE')
plt.show()

# %% [markdown]
# <head>
#     <link rel='stylesheet' href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style="background-color: black; color:white; border: 2px solid #fff87e; text-align:center; font-weight: bold; font-family: 'Montserrat', sans-serif; padding: 20px; border-radius:20px; font-size:20px">
#
# <h4>Bivariate Analysis</h4>
#
# </div>

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
sns.scatterplot(
    y=ndf2000['TOTAL_REVENUE'], x=ndf2000['AVG_MATH_8_SCORE'],
    size=ndf2000['TOTAL_REVENUE'], hue=ndf2000['TOTAL_REVENUE'],
    palette='flare')

plt.title("Average 8th Grade Math Scores Vs. Total Revenue", fontsize= 20)
plt.ylabel('Total Revenue')
plt.xlabel("Average 8th Grade Math Score")
plt.grid(True)  
plt.show()

# %% [markdown]
# <hr>

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(y=ndf2000['TOTAL_EXPENDITURE'], x=ndf2000['AVG_MATH_8_SCORE'],
                size=ndf2000['TOTAL_EXPENDITURE'], hue=ndf2000['TOTAL_EXPENDITURE'],
                palette = 'viridis')

plt.ylabel('Total Expenditure')
plt.title('Average 8th Grade Math Scores Vs. Total Expenditure')
plt.xlabel("Average 8th Grade Math Score")
plt.grid(True)  
plt.show()

# %% [markdown]
# <head>
#     <link rel='stylesheet' href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style="background-color: black; color:white; border: 2px solid #fff87e; text-align:center; font-weight: bold; font-family: 'Montserrat', sans-serif; padding: 20px; border-radius:20px; font-size:20px">
#
# <h4>Hypothesis Testing</h4>
#
# </div>

# %% [markdown]
# <div style="background-color:lightyellow; color:black; padding:20px;">
# <p>H<sub>0</sub>: Total Revenue has no statistical affect on Average 8th Grade Math Scores.</p>
#     <br>
# <p>H<sub>1</sub>sub>: Total Revenue has a statistically significant affect Average 8th Grade Math Scores.</p>
# </div>

# %%
column1 = ndf2000['TOTAL_REVENUE']
column2 = ndf2000['AVG_MATH_8_SCORE']

correlation_coefficient, p_value = sci.stats.pearsonr(column1, column2)

print(f"Pearson correlation coefficient: {correlation_coefficient}")
print(f"P-value: {p_value}")

if p_value < 0.05:  
    print("The correlation is statistically significant.")
else:
    print("The correlation is not statistically significant.")
# Out:
# Pearson correlation coefficient: -0.08174552235240531
# P-value: 0.5725132137761851
# The correlation is not statistically significant.

# %% [markdown]
# <div style="background-color:lightyellow; color:black; padding:20px;">
# Based on the Pearson Correlation Coeffficient we have failed to prove our alternative hypothesis.
# </div>

# %% [markdown]
# <hr>

# %% [markdown]
# <div style="background-color:lightyellow; color:black; padding:20px;">
# <p>H<sub>0</sub>: Total Expenditure has no statistical affect on Average 8th Grade Math Scores.</p>
#     <br>
# <p>H<sub>1</sub>sub>: Total Expenditure has a statistically significant affect Average 8th Grade Math Scores.</p>
# </div>

# %%
column1 = ndf2000['TOTAL_EXPENDITURE']
column2 = ndf2000['AVG_MATH_8_SCORE']

correlation_coefficient, p_value = sci.stats.pearsonr(column1, column2)

print(f"Pearson correlation coefficient: {correlation_coefficient}")
print(f"P-value: {p_value}")

if p_value < 0.05:  
    print("The correlation is statistically significant.")
else:
    print("The correlation is not statistically significant.")
# Out:
# Pearson correlation coefficient: -0.07819521798437282
# P-value: 0.5893582118913347
# The correlation is not statistically significant.

# %% [markdown]
# <div style="background-color:lightyellow; color:black; padding:20px;">
# While our P-value was slightly higher for TOTAL EXPENDITURE we failed to prove our alternative hypothesis.
# </div>

# %% [markdown]
# <head>
#     <link rel= "stylesheet" href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style=" width:95%; color: white; background-color:#00296b ; border: 3px solid black; border-radius:20px; padding:20px; font:ontserrat;">
#
# <h2>Conclusions</h2>
# </div>

# %% [markdown]
# <strong>Based on the analysis performed above we can answer our initial questions of:</strong>
# - Determine the correlation between total revenue and average 8th grade math scores
# - Determine the correlation between total expenditure and average 8th grade math scores
# - Identify the states with the most students
#
# <strong>Correlation between total revenue and 8th grade math scores:</strong><br>
# According to our analysis there is not a statistically significant correlation between total revenue and 8th grade math scores.
#
# <strong>Correlation between total expenditure and 8th grade math scores:</strong><br>
# Similarly to total revenue we were unable to find a statistically significant correlation between total expenditure and 8th grade math scores.
#
# <strong>States with highest enrollment of students:</strong><br>
# Our analysis indicated the following states have the most students enrolled: CALIFORNIA,
# TEXA,
# NEW_YO, K
# FLOR, DA
# ILLI, OIS
# , OHIO
# PENNSY, VANIA
# M, CHIGAN
# , GEORGIA
# N.EW_JERSEY

# %% [markdown]
# <head>
#     <link rel= "stylesheet" href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style=" width:95%; color: white; background-color:#00296b ; border: 3px solid black; border-radius:20px; padding:20px; font:ontserrat;">
#
# <h2>Additional Visualizaitons (Excel & Tableau)</h2>
# </div>

# %% [markdown]
# <div style="background-color:lightyellow; color:black; padding:20px;">
# While I could re-create the above visualizations in Excel and Tableau, I would like to analyize a different subset of this data. So I will create a new data frame and track the TOTAL_REVENUE, TOTAL_EXPENDITURE and AVG_MATH_8_SCORE across the top 10 states over a 10 year period.
# </div>

# %%
edf = ndf[(ndf['YEAR'] >2000) & (ndf['YEAR'] <=2010)]

edf.groupby('STATE')['ENROLL'].sum().sort_values(ascending=False).nlargest(10)
# Out:
# STATE
# CALIFORNIA        62291235.0
# TEXAS             43859349.0
# NEW_YORK          27904723.0
# FLORIDA           25923325.0
# ILLINOIS          20800683.0
# OHIO              17669150.0
# PENNSYLVANIA      17408097.0
# MICHIGAN          16765759.0
# GEORGIA           15668914.0
# NORTH_CAROLINA    13659808.0
# Name: ENROLL, dtype: float64

# %%
# List of states
states = [
    'CALIFORNIA', 'TEXAS', 'NEW_YORK', 'FLORIDA', 'ILLINOIS',
    'OHIO', 'PENNSYLVANIA', 'MICHIGAN', 'GEORGIA', 'NORTH_CAROLINA'
]

pd.set_option('display.max_rows', 500)

# Filter rows based on the specified states
edf = edf[edf['STATE'].isin(states)]
edf.groupby('STATE').apply(lambda x: x.head(100))
# Out:
#                             PRIMARY_KEY           STATE  YEAR     ENROLL  \
# STATE
# CALIFORNIA     463      2001_CALIFORNIA      CALIFORNIA  2001  6045030.0
#                514      2002_CALIFORNIA      CALIFORNIA  2002  6136915.0
#                565      2003_CALIFORNIA      CALIFORNIA  2003  6226552.0
#                616      2004_CALIFORNIA      CALIFORNIA  2004  6284502.0
#                667      2005_CALIFORNIA      CALIFORNIA  2005  6307022.0
#                718      2006_CALIFORNIA      CALIFORNIA  2006  6295994.0
#                769      2007_CALIFORNIA      CALIFORNIA  2007  6288686.0
#                820      2008_CALIFORNIA      CALIFORNIA  2008  6258421.0
#                871      2009_CALIFORNIA      CALIFORNIA  2009  6234155.0
#                922      2010_CALIFORNIA      CALIFORNIA  2010  6213958.0
# FLORIDA        468         2001_FLORIDA         FLORIDA  2001  2431884.0
#                519         2002_FLORIDA         FLORIDA  2002  2500179.0
# ...

# %%
#Creating a CSV for our new dataframe to create data viz in Excel and Tableau
edf.to_csv('US Education EDF.csv', index=False)

# %% [markdown]
# <head>
#     <link rel='stylesheet' href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style="background-color: black; color:white; border: 2px solid #fff87e; text-align:center; font-weight: bold; font-family: 'Montserrat', sans-serif; padding: 20px; border-radius:20px; font-size:20px">
#
# <h4>Excel Dashboard</h4>
#
# </div>

# %% [markdown]
# You can access the dashboard using the by looking in the file section of this repository.

# %% [markdown]
# ![US Education Excel Dashboard.png](attachment:39400cbc-087a-4475-9d42-97aeb81c85cb.png)

# %% [markdown]
# <head>
#     <link rel='stylesheet' href="https://fonts.googleapis.com/css?family=Montserrat">
# </head>
#
# <div style="background-color: black; color:white; border: 2px solid #fff87e; text-align:center; font-weight: bold; font-family: 'Montserrat', sans-serif; padding: 20px; border-radius:20px; font-size:20px">
#
# <h4>Tableau Dashboard</h4>
#
# </div>

# %% [markdown]
# You can check out the Tableau dashboard on tableau public using the <a href='https://public.tableau.com/app/profile/peige.malys/viz/USEducationMathScoreRevenueExpenditurebyYearDashboard/Dashboard1'>following link.</a>

# %% [markdown]
# ![US Education Tableau Dashboard.png](attachment:aa0bc568-e930-4496-97d1-73987806f351.png)
